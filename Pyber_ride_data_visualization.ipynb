# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics

# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
#plot the months along the x-axis and the fare on the y-axis using the plot() function
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
# Set x-axis and tick locations. we need an array that is the length of the DataFrame. 
#This will allow us to plot each month for each value in the array. With the NumPy module, 
#we create an array of numbers using the arange function for the length of the pyber_ride_df:
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data.set the tick locations for every value, or month, in the x-axis using list comprehension
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
#We add the xticks() function and pass in the tick_locations and the labels of the x-ticks, pyber_ride_df["Month"]
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
# first approach, we “chain” the bar() function to the plot() function
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
#second approach is to add the kind parameter to the plot() function
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()

# %% [markdown]
# ### Skill Drill
#
# Using the data from the PyBer ride DataFrame, create a bar chart with the following annotations and characteristics:
#
# - Add error bars.
# - Add caps to the error bars.
# - Change the color of the bars to sky blue.
# - Rotate the labels on the x-axis to horizontal.
# - Set the y-axis increment to every $5

# %%
#Import Dependencies
import statistics
import pandas as pd
import numpy as np

#define the x and y axis
x_axis = pyber_ride_df['Month']
y_axis = pyber_ride_df['Avg. Fare ($USD)']

# # Get the standard deviation of the average fare
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
# Create the bar chart
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='barh', xerr=stdev, capsize=3, color="skyblue")
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %% [markdown]
# ![What%20is%20the%20right%20chart.PNG](attachment:What%20is%20the%20right%20chart.PNG)

# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics
# Load in csv
ride_data_df = pd.read_csv("Resources/ride_data.csv")
city_data_df = pd.read_csv("Resources/city_data.csv")

# %%
#look at first 10 rows and columns
city_data_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
#look at last 10 rows and columns
city_data_df.tail(30)
# Out:
#                    city  driver_count      type
# 90        Barronchester            11  Suburban
# 91          Brandonfort            10  Suburban
# 92      East Danielview            22  Suburban
# 93       East Marymouth             5  Suburban
# 94          Mezachester            14  Suburban
# 95            Lewisland             4  Suburban
# 96           Josephside            25  Suburban
# 97            Davidfurt            23  Suburban
# 98        Nicolechester            19  Suburban
# 99       East Aaronbury             7  Suburban
# 100  North Richardhaven             1  Suburban
# 101       North Jeffrey            11  Suburban
# 102      South Jennifer             7     Rural
# 103        West Heather             4     Rural
# 104          Newtonview             1     Rural
# 105         North Holly             8     Rural
# 106         Michaelberg             6     Rural
# 107         Taylorhaven             1     Rural
# 108         Penaborough             6     Rural
# ...

# %%
#Find out the type
type(city_data_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Get the Number of Rows
len(city_data_df)
# Out:
# 120

# %%
# Get the Number of Columns
len(city_data_df.columns)
# Out:
# 3

# %%
# To show the different columns
print(city_data_df.columns)
# Out:
# Index(['city', 'driver_count', 'type'], dtype='object')

# %%
#discover basic statistics about the dataframe
ride_data_df.describe()
# Out:
#               fare       ride_id
# count  2375.000000  2.375000e+03
# mean     26.753112  4.887270e+12
# std      12.109465  2.907361e+12
# min       4.050000  3.218337e+08
# 25%      17.190000  2.381175e+12
# 50%      26.600000  4.748541e+12
# 75%      36.645000  7.461936e+12
# max      58.550000  9.991538e+12

# %%
#find the number of columns
len(ride_data_df.columns)
# Out:
# 4

# %%
#find out the number of rows
len(ride_data_df)
# Out:
# 2375

# %%
print(ride_data_df.columns)
# Out:
# Index(['city', 'date', 'fare', 'ride_id'], dtype='object')

# %%
#look at first 10 rows and columns
ride_data_df.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %%
#look at last 10 rows and columns
ride_data_df.tail(10)
# Out:
#                  city                 date   fare        ride_id
# 2365       Lake Jamie  2019-04-19 04:32:47  16.29  3518682119233
# 2366      North Holly  2019-03-18 10:38:05  40.34  3787775176860
# 2367      Michaelberg  2019-01-27 18:43:05  38.42   862622008020
# 2368       Lake Jamie  2019-04-29 01:58:44  54.22  2489264790267
# 2369     Bradshawfurt  2019-01-30 10:55:23  51.39  1328274868072
# 2370      Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371  Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372      North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373     West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374       Newtonview  2019-04-25 10:20:13  55.84  9990581345298

# %%
#look at all data -- looks like just running the whole dataframe gives both the head and tail without having to do it separately
ride_data_df
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %% [markdown]
# # Create a bubble chart for ridesharing data

# %%
ride_data_df['city'].unique()
# Out:
# array(['Lake Jonathanshire', 'South Michelleport', 'Port Samanthamouth',
#        'Rodneyfort', 'South Jack', 'South Latoya', 'New Paulville',
#        'Simpsonburgh', 'South Karenland', 'North Jasmine',
#        'New Kimberlyborough', 'West Angela', 'Roberthaven', 'North Jason',
#        'Williamsview', 'Leahton', 'West Anthony', 'New Paulton',
#        'West Patrickchester', 'Deanville', 'West Josephberg',
#        'West Samuelburgh', 'West Heidi', 'Loganberg', 'Huntermouth',
#        'Grahamburgh', 'Port Frank', 'East Kaylahaven', 'West Robert',
#        'North Markport', 'Richardfort', 'Reynoldsfurt', 'Justinberg',
#        'Martinezhaven', 'Jerryton', 'Lake Scottton', 'South Evanton',
#        'Rogerston', 'West Ericstad', 'Hurleymouth', 'Joneschester',
#        'Port Angela', 'Barajasview', 'West Christopherberg',
#        'New Jacobville', 'Port David', 'Valentineton', 'Carriemouth',
#        'Williamsstad', 'Royland', 'Karenberg', 'Christopherfurt',
# ...

# %%
city_data_df['type'].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
city_data_df['type'] == 'Suburban'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# Name: type, Length: 120, dtype: bool

# %%
len(ride_data_df['city'].unique())
# Out:
# 120

# %%
ride_data_df['fare'].mean()
# Out:
# 26.753111578947426

# %%
ride_data_df['fare'].describe()
# Out:
# count    2375.000000
# mean       26.753112
# std        12.109465
# min         4.050000
# 25%        17.190000
# 50%        26.600000
# 75%        36.645000
# max        58.550000
# Name: fare, dtype: float64

# %%
city_data_df.driver_count.describe()
# Out:
# count    120.000000
# mean      24.775000
# std       20.277678
# min        1.000000
# 25%        7.000000
# 50%       20.500000
# 75%       38.250000
# max       73.000000
# Name: driver_count, dtype: float64

# %%
# Get the number of data points from the Urban cities.
sum(city_data_df["type"]=="Urban")
# Out:
# 66

# %%
# Get the number of data points from the Urban cities.
sum(city_data_df["type"]=="Suburban")
# Out:
# 36

# %%
# Get the number of data points from the Urban cities.
sum(city_data_df["type"]=="Rural")
# Out:
# 18

# %% [markdown]
# ### Merge DataFrames
# Before we merge the DataFrames, let’s review each DataFrame.
#
# The columns in the city_data_df DataFrame are:
#
# - city
# - driver_count
# - type
#
# The columns in the ride_data_df are:
#
# - city
# - date
# - fare
# - ride_id

# %% [markdown]
# ![data-5-3-1-final_bubble_chart.png](attachment:data-5-3-1-final_bubble_chart.png)

# %% [markdown]
# For the bubble chart, we will need to plot the following:
#
# - The average fare for each type of city on the y-axis
# - The total number of rides for each type city on the x-axis
# - Make the size of each marker, or bubble, correlate to the average number of drivers for each type of city
#
# Here are the steps to create a bubble chart:
#
# - To get the average fare, we can use the Pandas mean() method for each city in the “fare” column.
# - To get the total number of rides for each city, we can use the Pandas count() method for each city in the “ride_id” column.
# - To make the bubble size correlate to the number of drivers for each city, we can get the average driver_count for each city.
#
# Completing the steps will be more efficient if we create separate DataFrames for each type and then create Data Series for each step.
#
# Let’s create three separate DataFrames, one for each type of city.
#
# Each new DataFrame can be created by filtering the pyber_data_df DataFrame where the city type is equal to Urban, Suburban, or Rural.

# %%
suburban = city_data_df["type"]=="Suburban"

# %%
suburban
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# Name: type, Length: 120, dtype: bool

# %%
urban = city_data_df["type"]=="Urban"

# %%
rural = city_data_df["type"]=="Rural"

# %%
# Get the columns and the rows that are not null.
city_data_df.isnull().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
# Get the unique values of the type of city.
city_data_df["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
# Get the columns and the rows that are not null.
ride_data_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
# Get the columns and the rows that are not null.
ride_data_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
# Get the data types of each column.
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the DataFrame
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban
